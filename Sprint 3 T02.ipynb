# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/merceborras/Downloads/archive/DelayedFlights.csv')

# %%
#Exercici 1
df
# Out:
#          Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0                 0  2008      1           3          4   2003.0        1955
# 1                 1  2008      1           3          4    754.0         735
# 2                 2  2008      1           3          4    628.0         620
# 3                 4  2008      1           3          4   1829.0        1755
# 4                 5  2008      1           3          4   1940.0        1915
# ...             ...   ...    ...         ...        ...      ...         ...
# 1936753     7009710  2008     12          13          6   1250.0        1220
# 1936754     7009717  2008     12          13          6    657.0         600
# 1936755     7009718  2008     12          13          6   1007.0         847
# 1936756     7009726  2008     12          13          6   1251.0        1240
# 1936757     7009727  2008     12          13          6   1110.0        1103
#
# ...

# %%
df_net = df.drop(['Cancelled', 'Diverted', 'CancellationCode','TaxiIn', 'TaxiOut', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay','CRSDepTime', 'CRSArrTime', 'UniqueCarrier', 'TailNum', 'ActualElapsedTime', 'CRSElapsedTime'], axis=1)
df_net.sample(200000)
df_net
# Out:
#         Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  \
# 0                0  2008      1           3          4   2003.0   2211.0
# 1                1  2008      1           3          4    754.0   1002.0
# 2                2  2008      1           3          4    628.0    804.0
# 3                4  2008      1           3          4   1829.0   1959.0
# 4                5  2008      1           3          4   1940.0   2121.0
# ...            ...   ...    ...         ...        ...      ...      ...
# 199995      645671  2008      2          14          4   2143.0   2303.0
# 199996      645672  2008      2          14          4   1448.0   1701.0
# 199997      645674  2008      2          14          4   1853.0   2102.0
# 199998      645676  2008      2          14          4   1642.0   1906.0
# 199999      645679  2008      2          14          4   2110.0   2316.0
#
#         FlightNum  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# ...

# %%
#He seleccionat un nombre de columnes amb les quals pogués treballar fàcilment i el contingut del qual
#em sigués comprensible

# %%
#Exercici 2
#2.2 Dades faltants per columna
df_net.isnull().sum(axis=1).sample(200000)
# Out:
# 100616    0
# 64509     0
# 46466     0
# 20915     2
# 16566     0
#          ..
# 91617     0
# 16966     2
# 64452     0
# 32485     0
# 171872    2
# Length: 200000, dtype: int64

# %%
#Exercici 2
#Velocitat mitjana de vol + vols arribats tard
df_net["Time"] = (df_net["ArrTime"] - df_net["DepTime"]).sample(200000)
df_net
# Out:
#         Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  \
# 0                0  2008      1           3          4   2003.0   2211.0
# 1                1  2008      1           3          4    754.0   1002.0
# 2                2  2008      1           3          4    628.0    804.0
# 3                4  2008      1           3          4   1829.0   1959.0
# 4                5  2008      1           3          4   1940.0   2121.0
# ...            ...   ...    ...         ...        ...      ...      ...
# 199995      645671  2008      2          14          4   2143.0   2303.0
# 199996      645672  2008      2          14          4   1448.0   1701.0
# 199997      645674  2008      2          14          4   1853.0   2102.0
# 199998      645676  2008      2          14          4   1642.0   1906.0
# 199999      645679  2008      2          14          4   2110.0   2316.0
#
#         FlightNum  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# ...

# %%
df_net["AverageVel"] = (df_net["Distance"] / df_net["Time"]).sample(200000)
df_net
# Out:
#         Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  \
# 0                0  2008      1           3          4   2003.0   2211.0
# 1                1  2008      1           3          4    754.0   1002.0
# 2                2  2008      1           3          4    628.0    804.0
# 3                4  2008      1           3          4   1829.0   1959.0
# 4                5  2008      1           3          4   1940.0   2121.0
# ...            ...   ...    ...         ...        ...      ...      ...
# 199995      645671  2008      2          14          4   2143.0   2303.0
# 199996      645672  2008      2          14          4   1448.0   1701.0
# 199997      645674  2008      2          14          4   1853.0   2102.0
# 199998      645676  2008      2          14          4   1642.0   1906.0
# 199999      645679  2008      2          14          4   2110.0   2316.0
#
#         FlightNum  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# ...

# %%
#Exercici 2
#Vol + llarg 
df_net["Time"].idxmax()
print(df_net.loc[[181365]])
# Out:
#         Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  \
# 181365      592839  2008      1           4          5    652.0   1810.0
#
#         FlightNum  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 181365       1820    230.0     240.0       7.0    SFO  CVG      2036
#
#         CarrierDelay  WeatherDelay  AverageVel    Time
# 181365           7.0           0.0    1.758204  1158.0

# %%
#Vol + endarrerit
df_net["ArrDelay"].idxmax()
print(df_net.loc[[163379]])
# Out:
#         Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  ArrTime  \
# 163379      527950  2008      1           5          6    800.0   1452.0
#
#         FlightNum  AirTime  ArrDelay  DepDelay Origin Dest  Distance  \
# 163379       2398    207.0    1525.0    1275.0    EGE  MIA      1811
#
#         CarrierDelay  WeatherDelay  AverageVel   Time
# 163379        1158.0           0.0    2.777607  652.0

# %%
df.to_excel(r'/Users/merceborras/Downloads/archive/Flights_Delays.xlsx', sheet_name='Flights_Delays.xlsx', index=False)
